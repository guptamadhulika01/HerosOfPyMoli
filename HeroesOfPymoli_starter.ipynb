# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import os
import pandas as pd
import csv


# File to Load (Remember to Change These)
csv_file = "Resources/purchase_data.csv"
csvpath = os.path.join("Resources", "purchase_data.csv")
print(csvpath)

# Read Purchasing File and store into Pandas data frame

with open(csv_file, newline="") as purchaseFile:
    csvreader = csv.reader(purchaseFile, delimiter=",")
    print(csvreader) 
    
    purchase_df = pd.read_csv(purchaseFile)
# Out:
# Resources\purchase_data.csv
# ...

# %%
#print head to chack if it is accessing the csv file 
purchase_df.head()
# Out:
#    Purchase ID            SN  Age Gender  Item ID  \
# 0            0  Adairialis76   20   Male      108
# 1            1   Adastirin33   40   Male      143
# 2            2        Aeda94   24   Male       92
# 3            3        Aela59   24   Male      100
# 4            4     Aelaria33   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players
#  purchase_df["SN"].unique()

# %%
# Total No. of Players


uniquePlayers = len(purchase_df["SN"].unique())
uniquePlayers
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %%
#Run basic calculations to obtain number of unique items, average price, etc.

# %%
# calculate no of unique items through column( Item ID)
Itemcount = len( purchase_df["Item ID"].unique())
Itemcount
# Out:
# 183

# %%
# to calculate average price of items 

averagePrice = purchase_df["Price"].mean()
averagePrice
# Out:
# 3.050987179487176

# %%
#total no of purchases made
purchaseCount = purchase_df["SN"].count()
purchaseCount
# Out:
# 780

# %%
# Total Revenue
totalRevenue = purchase_df["Price"].sum()
totalRevenue
# Out:
# 2379.77

# %%
#Create a summary data frame to hold the results

# %%
purchasingAnalysis_df = pd.DataFrame(columns=['Total No. Of Players','Avearge Purchase Price','No. Of Unique Items', 'Total No. of Purchases Made', 'Total Revenue Generated'])
purchasingAnalysisNew_df =purchasingAnalysis_df.append({'Total No. Of Players': uniquePlayers,'Avearge Purchase Price':averagePrice, 'No. Of Unique Items': Itemcount, 'Total No. of Purchases Made': purchaseCount, 'Total Revenue Generated':totalRevenue}, ignore_index=True)
purchasingAnalysisNew_df
# Out:
#    Total No. Of Players  Avearge Purchase Price  No. Of Unique Items  \
# 0                 576.0                3.050987                183.0
#
#    Total No. of Purchases Made  Total Revenue Generated
# 0                        780.0                  2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#percentage and count of male Players
malePlayers = (purchase_df['Gender'] == "Male").value_counts()
malePlayers[True]
# Out:
# 652

# %%
#percentage and count of female Players
femalePlayers = (purchase_df['Gender'] == "Female").value_counts()
femalePlayers[True]
# Out:
# 113

# %%
#Percentage and count of Other / Non-Disclosed
nondisclosedPlayers = (purchase_df['Gender'] == "Other / Non-Disclosed").value_counts()
nondisclosedPlayers[True]
# Out:
# 15

# %%
#total no of player = malePalyers + femalePlayers + nondisclosed players
totalPlayers = malePlayers + femalePlayers + nondisclosedPlayers
totalPlayers [True]
# Out:
# 780

# %%
#percentage of male players
PercentageOfMalePlayers = (malePlayers/totalPlayers)*100
PercentageOfMalePlayers[True]
# Out:
# 83.58974358974359

# %%
PercentageOffemalePlayers = (femalePlayers/totalPlayers)*100
PercentageOffemalePlayers[True]
# Out:
# 14.487179487179489

# %%
PercentageOfnondisclosedPlayers = (nondisclosedPlayers/totalPlayers)*100
PercentageOfnondisclosedPlayers[True]
# Out:
# 1.9230769230769231

# %%
# Gender Demographics Report

gender_df=pd.DataFrame(columns=['No. Of Male Players','Percentage of Male Players','No. OF Female Players','Percentage of Female Players','Non-disclosed Players','Percentage of Non-disclosed Players'])

genderDemographics_dfNew =gender_df.append({"No. Of Male Players": malePlayers[True], " Percentage of Male Players":PercentageOfMalePlayers[True],"No. OF Female Players": femalePlayers[True], " Percentage of Female Players": PercentageOffemalePlayers[True], "No. Of Undisclosed Players":nondisclosedPlayers[True]," Percentage of Undisclosed Players":PercentageOfnondisclosedPlayers[True] },ignore_index=True)                                   
genderDemographics_dfNew
# Out:
#    No. Of Male Players  Percentage of Male Players  No. OF Female Players  \
# 0                652.0                         NaN                  113.0
#
#    Percentage of Female Players  Non-disclosed Players  \
# 0                           NaN                    NaN
#
#    Percentage of Non-disclosed Players   Percentage of Female Players  \
# 0                                  NaN                      14.487179
#
#     Percentage of Male Players   Percentage of Undisclosed Players  \
# 0                    83.589744                            1.923077
#
#    No. Of Undisclosed Players
# 0                        15.0

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#purchase count by gender per person
purchase_df.groupby(['Gender']).Price.count()
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Price, dtype: int64

# %%
#Average Purchase per Person by Gender
purchase_df.groupby(['Gender']).Price.mean()
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
#totalpurchase_df.groupby('Gender').Price.mean()purcha se value by gender
purchase_df.groupby('Gender').Price.sum()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
#Summary DataFrame for Purchasing Analysis
purchasingAgeAnalysis_df1 = pd.DataFrame({
    "Gender": ["Male","Female","Non-Disclosed"],
    "Purchase Count": [652,113,15], 
    "Average Purchase": [3.01,3.20,15],
    "Total Purchase": [1967.64, 361.64, 50.19]
     })
purchasingAgeAnalysis_df1
# Out:
#           Gender  Purchase Count  Average Purchase  Total Purchase
# 0           Male             652              3.01         1967.64
# 1         Female             113              3.20          361.64
# 2  Non-Disclosed              15             15.00           50.19

# %%
#avg purchase price by gender per person for Female
avgpurchaseFemale = pd.DataFrame(dfFemale.groupby(dfFemale['SN']).Price.mean())
avgpurchaseFemale
# Out:
#                  Price
# SN
# Aelollo59        2.890
# Aeral43          4.900
# Aethedru70       4.180
# Aidai73          1.330
# Airi27           3.790
# Ali84            3.700
# Anallorgue57     1.980
# Ardcil81         4.230
# Arin32           3.750
# Assastnya25      3.470
# Assilsan72       2.220
# Assim27          1.160
# Assosia88        3.940
# Chadista79       1.330
# Chadistaya75     2.940
# Chadolyla44      1.790
# Chadossa56       4.430
# Chamassasya86    1.870
# Chamimla85       2.480
# Chamistast30     3.930
# Chamjask73       4.480
# Chanilsast61     2.890
# Chanirra79       3.530
# Chanosia60       2.210
# Chanosian48      2.280
# Ealiril69        1.400
# Ealrion88        4.600
# Ethralista69     2.730
# Ethron58         4.740
# Eulasuir89       4.400
# ...                ...
# Phaena87         2.420
# Pheosrinudeu70   1.330
# Pheosurllorin41  3.530
# Philodil43       4.840
# Phyali88         4.430
# Poshilsa82       4.580
# Quaecjask96      3.740
# ...

# %%
#avg purchase price by gender per person for male
avgpurchasemale = pd.DataFrame(dfMale.groupby(dfMale['SN']).Price.mean())
avgpurchasemale
# Out:
#                     Price
# SN
# Adairialis76     3.530000
# Adastirin33      1.560000
# Aeda94           4.880000
# Aela59           3.270000
# Aelaria33        1.440000
# Aelastirin39     2.895000
# Aelidru27        2.670000
# Aelin32          2.920000
# Aelly27          3.425000
# Aellynun67       1.700000
# Aellyria80       4.860000
# Aelollo59        2.520000
# Aenarap34        1.760000
# Aeral68          4.640000
# Aeral97          4.600000
# Aeralria27       1.480000
# Aeri84           3.400000
# Aerillorin70     3.190000
# Aerithllora36    2.920000
# Aerithnucal56    3.090000
# Aerithnuphos61   4.320000
# Aerithriaphos45  3.160000
# Aerithriaphos46  2.940000
# Aesri53          4.480000
# Aesty53          3.235000
# Aestysu37        3.225000
# Aesur96          3.150000
# Aesurstilis64    2.050000
# Aidai53          3.140000
# Aidai61          1.560000
# ...                   ...
# Undirrasta89     2.500000
# Undista85        4.140000
# Undjask33        1.750000
# ...

# %%
#avg purchase price by gender per person for Non-Disclosed
avgpurchaseNonDisclosed = pd.DataFrame(dfNondisclosed.groupby(dfNondisclosed['SN']).Price.mean())
avgpurchaseNonDisclosed
# Out:
#                 Price
# SN
# Aelin32          3.58
# Aeralstical35    3.81
# Assehoan67       4.40
# Chadista79       4.75
# Filurarn35       3.39
# Frichaststa61    3.55
# Frichirranya75   3.94
# Hirirap39        3.45
# Ilosia37         2.22
# Jiskimya77       1.33
# Lisosia93        3.94
# Phaestycal84     3.10
# Seolollo93       2.18
# Siala43          3.45
# Yadaisuir65      3.10

# %%
#purchaseav total per person(groupby gender)(groupby SN(Name of the buyer) )

TotalpurchaseFemale = pd.DataFrame(dfFemale.groupby(dfFemale['SN']).Price.sum())
TotalpurchaseFemale
# Out:
#                  Price
# SN
# Aelollo59         2.89
# Aeral43           4.90
# Aethedru70        4.18
# Aidai73           1.33
# Airi27            3.79
# Ali84             3.70
# Anallorgue57      1.98
# Ardcil81          4.23
# Arin32            3.75
# Assastnya25       3.47
# Assilsan72        2.22
# Assim27           1.16
# Assosia88         3.94
# Chadista79        1.33
# Chadistaya75      2.94
# Chadolyla44       1.79
# Chadossa56        4.43
# Chamassasya86     1.87
# Chamimla85        2.48
# Chamistast30      3.93
# Chamjask73        4.48
# Chanilsast61      2.89
# Chanirra79        3.53
# Chanosia60        2.21
# Chanosian48       2.28
# Ealiril69         1.40
# Ealrion88         4.60
# Ethralista69      2.73
# Ethron58          4.74
# Eulasuir89        4.40
# ...                ...
# Phaena87          2.42
# Pheosrinudeu70    1.33
# Pheosurllorin41   3.53
# Philodil43        4.84
# Phyali88          4.43
# Poshilsa82        4.58
# Quaecjask96       3.74
# ...

# %%
#Total Purchase Per Person for Males
Totalpurchasemale = pd.DataFrame(dfMale.groupby(dfMale['SN']).Price.sum())
Totalpurchasemale
# Out:
#                  Price
# SN
# Adairialis76      3.53
# Adastirin33       1.56
# Aeda94            4.88
# Aela59            3.27
# Aelaria33         1.44
# Aelastirin39      5.79
# Aelidru27         2.67
# Aelin32           5.84
# Aelly27           6.85
# Aellynun67        1.70
# Aellyria80        4.86
# Aelollo59         2.52
# Aenarap34         1.76
# Aeral68           4.64
# Aeral97           4.60
# Aeralria27        1.48
# Aeri84            3.40
# Aerillorin70      3.19
# Aerithllora36     5.84
# Aerithnucal56     3.09
# Aerithnuphos61    4.32
# Aerithriaphos45   3.16
# Aerithriaphos46   2.94
# Aesri53           4.48
# Aesty53           6.47
# Aestysu37         6.45
# Aesur96           3.15
# Aesurstilis64     2.05
# Aidai53           3.14
# Aidai61           1.56
# ...                ...
# Undirrasta89      2.50
# Undista85         4.14
# Undjask33         1.75
# Undjaskla97       5.47
# Undosian34        8.66
# Undotesta33       1.44
# Wailin72          3.49
# ...

# %%
#total Purchase per person for nondisclosed

totalpurchaseNonDisclosed = pd.DataFrame(dfNondisclosed.groupby(dfNondisclosed['SN']).Price.sum())
totalpurchaseNonDisclosed
# Out:
#                 Price
# SN
# Aelin32          3.58
# Aeralstical35    3.81
# Assehoan67       4.40
# Chadista79       4.75
# Filurarn35       3.39
# Frichaststa61    3.55
# Frichirranya75   3.94
# Hirirap39        3.45
# Ilosia37         2.22
# Jiskimya77       1.33
# Lisosia93        3.94
# Phaestycal84     3.10
# Seolollo93       2.18
# Siala43          3.45
# Yadaisuir65      3.10

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
purchase_df.dropna()
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0     Adairialis76   20                   Male      108
# 1              1      Adastirin33   40                   Male      143
# 2              2           Aeda94   24                   Male       92
# 3              3           Aela59   24                   Male      100
# 4              4        Aelaria33   23                   Male      131
# 5              5     Aelastirin39   22                   Male       81
# 6              6     Aelastirin39   36                   Male      169
# 7              7        Aelidru27   20                   Male      162
# 8              8          Aelin32   22                   Male       21
# 9              9          Aelin32   35  Other / Non-Disclosed      136
# 10            10          Aelin32   23                   Male       95
# 11            11          Aelly27   23                   Male      162
# ...

# %%
print(purchase_df["Age"].max())
print(purchase_df["Age"].min())
# Out:
# 45
# 7

# %%
# Create bins in which to place values based on age
bins =[0, 9, 13, 17, 21, 25, 29, 33, 37,  41, 45 ,49,  ]

# Create labels for these bins
group_labels = ["0 to 10", "10 to 14", "15 to 18","19 to 22","23 to 26", "27 to 30", "31 to 34" , "35 to 38", "39 to 42" , "43 to 46" , "47 to 50"]

# %%
# Slice the data and place it into bins
pd.cut(purchase_df["Age"], bins, labels=group_labels).head(10)
# Out:
# 0    19 to 22
# 1    39 to 42
# 2    23 to 26
# 3    23 to 26
# 4    23 to 26
# 5    23 to 26
# 6    35 to 38
# 7    19 to 22
# 8    23 to 26
# 9    35 to 38
# Name: Age, dtype: category
# Categories (11, object): [0 to 10 < 10 to 14 < 15 to 18 < 19 to 22 ... 35 to 38 < 39 to 42 < 43 to 46 < 47 to 50]

# %%
purchase_df["View Group"] = pd.DataFrame(pd.cut(purchase_df["Age"], bins, labels=group_labels))
purchase_df.head()
# Out:
#    Purchase ID            SN  Age Gender  Item ID  \
# 0            0  Adairialis76   20   Male      108
# 1            1   Adastirin33   40   Male      143
# 2            2        Aeda94   24   Male       92
# 3            3        Aela59   24   Male      100
# 4            4     Aelaria33   23   Male      131
#
#                                    Item Name  Price View Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53   19 to 22
# 1                          Frenzied Scimitar   1.56   39 to 42
# 2                               Final Critic   4.88   23 to 26
# 3                                Blindscythe   3.27   23 to 26
# 4                                       Fury   1.44   23 to 26

# %%
#Calculate the numbers of players in each group and percentages by age group
purchase_group = purchase_df.groupby("View Group")

#Players_group = purchase_df.groupby("View Group")
noOfPlayers = pd.DataFrame(purchase_group["SN"].count())
noOfPlayers
# Out:
#              SN
# View Group
# 0 to 10      23
# 10 to 14     26
# 15 to 18     89
# 19 to 22    210
# 23 to 26    263
# 27 to 30     42
# 31 to 34     64
# 35 to 38     35
# 39 to 42     23
# 43 to 46      5

# %%
# calculate the percentage of players in each group
totalNoOfPlayers = purchase_df["SN"].count()
totalNoOfPlayers
percentageOfPlayersInEachBin =pd.DataFrame((((noOfPlayers/totalNoOfPlayers  )*100)))
percentageOfPlayersInEachBin["SN"] = percentageOfPlayersInEachBin["SN"].map("{:.2f}".format)
percentageOfPlayersInEachBin
# Out:
#                SN
# View Group
# 0 to 10      2.95
# 10 to 14     3.33
# 15 to 18    11.41
# 19 to 22    26.92
# 23 to 26    33.72
# 27 to 30     5.38
# 31 to 34     8.21
# 35 to 38     4.49
# 39 to 42     2.95
# 43 to 46     0.64

# %%
#Create a summary data frame to hold the results
#Binned Summary Results
Binned_df = pd.DataFrame({
    "Bin Ranges": ["0 to 10", "10 to 14", "15 to 18","19 to 22","23 to 26", "27 to 30", "31 to 34" , "35 to 38", "39 to 42" , "43 to 46" ],
    "No. Of Players in each Bin Range": [23, 26, 89, 210, 263, 42, 64, 35, 23, 5], 
    "% Of Players in each Bin Range": [2.95, 3.33, 11.41, 26.92, 33.72, 5.38, 8.21, 4.49, 2.95, 0.64]
})
Binned_df
# Out:
#   Bin Ranges  No. Of Players in each Bin Range  % Of Players in each Bin Range
# 0    0 to 10                                23                            2.95
# 1   10 to 14                                26                            3.33
# 2   15 to 18                                89                           11.41
# 3   19 to 22                               210                           26.92
# 4   23 to 26                               263                           33.72
# 5   27 to 30                                42                            5.38
# 6   31 to 34                                64                            8.21
# 7   35 to 38                                35                            4.49
# 8   39 to 42                                23                            2.95
# 9   43 to 46                                 5                            0.64

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#purchase count as per bin values
purchase_group = purchase_df.groupby("View Group")
purchase_group_count = pd.DataFrame(purchase_group["Price"].count())

# %%
#Average purchase Price as per bin values
purchase_group_average = pd.DataFrame(purchase_group["Price"].mean())
purchase_group_average
purchase_group_average["Price"] = purchase_group_average["Price"].map("{:.2f}".format)
purchase_group_average
# Out:
#            Price
# View Group
# 0 to 10     3.35
# 10 to 14    2.92
# 15 to 18    3.01
# 19 to 22    3.08
# 23 to 26    3.05
# 27 to 30    2.65
# 31 to 34    3.00
# 35 to 38    3.21
# 39 to 42    3.51
# 43 to 46    3.00

# %%
#Total Purchase Value as per Bin Values
purchase_group_total = pd.DataFrame(purchase_group["Price"].sum())
purchase_group_total
# Out:
#              Price
# View Group
# 0 to 10      77.13
# 10 to 14     75.87
# 15 to 18    267.60
# 19 to 22    647.26
# 23 to 26    800.90
# 27 to 30    111.10
# 31 to 34    191.87
# 35 to 38    112.33
# 39 to 42     80.72
# 43 to 46     14.99

# %%
#Average Purchase total per Person as per bin values 
Avgpurchase_group_total_per_person = (pd.DataFrame(purchase_group[["SN","Price"]].mean()))
Avgpurchase_group_total_per_person
# Out:
#                Price
# View Group
# 0 to 10     3.353478
# 10 to 14    2.918077
# 15 to 18    3.006742
# 19 to 22    3.082190
# 23 to 26    3.045247
# 27 to 30    2.645238
# 31 to 34    2.997969
# 35 to 38    3.209429
# 39 to 42    3.509565
# 43 to 46    2.998000

# %%
#Create a summary data frame to hold the results
#Purchasing Age Analysis

purchasingAgeAnalysis_df = pd.DataFrame({
    "Bin Ranges": ["0 to 10", "10 to 14", "15 to 18","19 to 22","23 to 26", "27 to 30", "31 to 34" , "35 to 38", "39 to 42" , "43 to 46" ],
    "Purchase Count": [23, 26, 89, 210, 263, 42, 64, 35, 23,5], 
    "Average Purchase": [3.35, 2.92, 3.01, 3.08, 3.05, 2.65, 3.00, 3.21, 3.51, 3.00],
    "Total Purchase": [77.13, 75.87, 267.26, 647.26, 800.90, 111.10, 191.87, 112.33, 80.72, 14.99], 
    "Average Purchase Per Person": [3.35, 2.92, 3.01, 3.08, 3.05, 2.65, 3.00, 3.21, 3.51, 3.00]
})
purchasingAgeAnalysis_df
# Out:
#   Bin Ranges  Purchase Count  Average Purchase  Total Purchase  \
# 0    0 to 10              23              3.35           77.13
# 1   10 to 14              26              2.92           75.87
# 2   15 to 18              89              3.01          267.26
# 3   19 to 22             210              3.08          647.26
# 4   23 to 26             263              3.05          800.90
# 5   27 to 30              42              2.65          111.10
# 6   31 to 34              64              3.00          191.87
# 7   35 to 38              35              3.21          112.33
# 8   39 to 42              23              3.51           80.72
# 9   43 to 46               5              3.00           14.99
#
#    Average Purchase Per Person
# 0                         3.35
# 1                         2.92
# 2                         3.01
# 3                         3.08
# 4                         3.05
# 5                         2.65
# 6                         3.00
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Sort the total purchase value column in descending order
purchase_group_total = pd.DataFrame(purchase_group["Price"].sum())
# sort as per highest purchase per group
descended = pd.DataFrame(purchase_group_total.sort_values('Price',ascending = False))
descended
# Out:
#              Price
# View Group
# 23 to 26    800.90
# 19 to 22    647.26
# 15 to 18    267.60
# 31 to 34    191.87
# 35 to 38    112.33
# 27 to 30    111.10
# 39 to 42     80.72
# 0 to 10      77.13
# 10 to 14     75.87
# 43 to 46     14.99

# %%
# Highest Spender Summary Table

highestSpenders_df = pd.DataFrame({
    "Bin Ranges": ["0 to 10", "10 to 14", "15 to 18","19 to 22","23 to 26", "27 to 30", "31 to 34" , "35 to 38", "39 to 42" , "43 to 46" ],
    "Total Purchase Value per Age Group": [800.90, 647.26, 267.69, 191.87, 112.33, 111.10, 80.72, 77.13, 75.87, 14.99], 
    "Highest Spenders per Age Range": ["Highest Spenders", "Runnerup 1", "Runnerup 2", "3rd Runnerup", "Average", "Lowest Spender Runnerup4",
                                       "Lowest Spender Runnerup3","Lowest Spender Runnerup2 ", "Lowest Spender Runnerup4",
                                       "Winneramongst Lowest Spender "]})
highestSpenders_df
# Out:
#   Bin Ranges  Total Purchase Value per Age Group  \
# 0    0 to 10                              800.90
# 1   10 to 14                              647.26
# 2   15 to 18                              267.69
# 3   19 to 22                              191.87
# 4   23 to 26                              112.33
# 5   27 to 30                              111.10
# 6   31 to 34                               80.72
# 7   35 to 38                               77.13
# 8   39 to 42                               75.87
# 9   43 to 46                               14.99
#
#   Highest Spenders per Age Range
# 0               Highest Spenders
# 1                     Runnerup 1
# 2                     Runnerup 2
# 3                   3rd Runnerup
# 4                        Average
# 5       Lowest Spender Runnerup4
# 6       Lowest Spender Runnerup3
# 7      Lowest Spender Runnerup2
# 8       Lowest Spender Runnerup4
# 9  Winneramongst Lowest Spender

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# create a new list with desired columns & display the head 
popularItems_df = pd.DataFrame(purchase_df[["Item ID","Item Name", "Price"]])
popularItems_df.set_index('Item ID', inplace=True)
popularItems_df.head()
# Out:
#                                          Item Name  Price
# Item ID
# 108      Extraction, Quickblade Of Trembling Hands   3.53
# 143                              Frenzied Scimitar   1.56
# 92                                    Final Critic   4.88
# 100                                    Blindscythe   3.27
# 131                                           Fury   1.44

# %%
#groupby Item ID and Item Name, obtain Purchase Count; sort by descending order
groupedItems = pd.DataFrame(popularItems_df.groupby(['Item ID','Item Name']).Price.count())
groupedItems = groupedItems.rename(columns = {"Item ID":" Item ID", "Item Name":"Most Profitable Items", "Price": "Count Of Items "})
#descendedgroupedItems = pd.DataFrame(groupedItems.sort_values('Price',ascending = False))
groupedItems.head()
# Out:
#                             Count Of Items
# Item ID Item Name
# 0       Splinter                          4
# 1       Crucifer                          3
# 2       Verdict                           6
# 3       Phantomlight                      6
# 4       Bloodlord's Fetish                5

# %%
#Merge DataFrame on outer Join to add columns
#>head() giving silly results as the Item ID is repeated several Item. 
df_outer = pd.merge(popularItems_df, groupedItems, on='Item ID', how='outer')

# %%
#Total Revenue grouped by Item ID and Item Name
TotalRevenue= pd.DataFrame(popularItems_df.groupby(['Item ID','Item Name']).sum())
TotalRevenue = TotalRevenue.rename(columns = {"Item ID":" Item ID", "Item Name":"Most Profitable Items", "Price": "Total Revenue"})
TotalRevenue.head()
# Out:
#                             Total Revenue
# Item ID Item Name
# 0       Splinter                     5.12
# 1       Crucifer                     9.78
# 2       Verdict                     14.88
# 3       Phantomlight                14.94
# 4       Bloodlord's Fetish           8.50

# %%
#Merge DataFrame on outer Join to add columns
#>head() giving silly results as the Item ID is repeated several Item. 
#delete duplicate rows form the DataFrame
df_outer1 = pd.merge(df_outer, TotalRevenue, on='Item ID', how='outer')
DropDuplicates = pd.DataFrame(df_outer1.drop_duplicates())
DropDuplicates.head()
# Out:
#                                          Item Name  Price  Count Of Items   \
# Item ID
# 108      Extraction, Quickblade Of Trembling Hands   3.53                9
# 143                              Frenzied Scimitar   1.56                6
# 92                                    Final Critic   4.88                8
# 100                                    Blindscythe   3.27                5
# 131                                           Fury   1.44                5
#
#          Total Revenue
# Item ID
# 108              31.77
# 143               9.36
# 92               39.04
# 100              16.35
# 131               7.20

# %%
#Sort Purchase value in descending order

sortedTotalPurchaseValue = pd.DataFrame(DropDuplicates.sort_values('Total Revenue', ascending=False))
sortedTotalPurchaseValue.head()
# Out:
#                                             Item Name  Price  Count Of Items   \
# Item ID
# 178      Oathbreaker, Last Hope of the Breaking Storm   4.23               12
# 82                                            Nirvana   4.90                9
# 145                              Fiery Glass Crusader   4.58                9
# 92                                       Final Critic   4.88                8
# 103                                    Singed Scalpel   4.35                8
#
#          Total Revenue
# Item ID
# 178              50.76
# 82               44.10
# 145              41.22
# 92               39.04
# 103              34.80

# %%
# Display summary Table for most popular item( by counts)
mostPopularItemsByCount = pd.DataFrame({
    "Item ID": [ "178" ],
    "Item Name": ["Oathbreaker, Last Hope of the Breaking Storm"], 
    "Count Of Items": [12]})
mostPopularItemsByCount
# Out:
#   Item ID                                     Item Name  Count Of Items
# 0     178  Oathbreaker, Last Hope of the Breaking Storm              12

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Most Profitable Items by Purchase value(Total Revenue)
sortedTotalPurchaseValue = pd.DataFrame(DropDuplicates.sort_values('Total Revenue', ascending=False))
sortedTotalPurchaseValue.head()
# Out:
#                                             Item Name  Price  Count Of Items   \
# Item ID
# 178      Oathbreaker, Last Hope of the Breaking Storm   4.23               12
# 82                                            Nirvana   4.90                9
# 145                              Fiery Glass Crusader   4.58                9
# 92                                       Final Critic   4.88                8
# 103                                    Singed Scalpel   4.35                8
#
#          Total Revenue
# Item ID
# 178              50.76
# 82               44.10
# 145              41.22
# 92               39.04
# 103              34.80
